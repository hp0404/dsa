# %%
from dsa import Documents

# %%
# %%timeit -n1 -r1
# 4min 6s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# поки тестую на одному файлі, в планах - отримувати дані через API
docs = Documents.from_json(
    "../data/20210507000000_20210508000000.json",
    normalize_values=True
)
docs.process_documents()

# %%
# оригінальні дані, перший документ
print(docs.raw_data[0])
# Out:
# {'CAUSE_NUMBER': '913/680/17', 'CAUSE_PROC_NUM': '18/913/66/20', 'DOC_CREATE_DATE': '1502950542000', 'DOC_DBID': '12', 'DOC_ID': '1981349', 'EDRSR_CODE_2007': '5014', 'JUDGES': 'Суддя-доповідач: Корнієнко В.В.', 'DOC_HTML': '...'}

# %%
# опрацьовані дані, перший документ
print(docs.processed_data[0])
# Out:
# {'CAUSE_NUMBER': '913/680/17', 'CAUSE_PROC_NUM': '18/913/66/20', 'DOC_CREATE_DATE': '1502950542000', 'DOC_DBID': '12', 'DOC_ID': '1981349', 'EDRSR_CODE_2007': '5014', 'JUDGES': 'Суддя-доповідач: Корнієнко В.В.', 'FILENAME': '5014_1981349.html', 'DOCID': '1981349', 'DOCORGID': '12', 'COURTNAME': 'Господарський суд Луганської області', 'CAUSECOURT': '5014', 'CAUSECOURT2013': '913', 'CAUSENUM': '913/680/17', 'CAUSEDATE': '17.08.2017', 'DOCDATE': '17.08.2017', 'DOCTYPE': '0', 'CAUSETYPE': 'господарська', 'CAUSELOCATION': 'перша', 'HEARINGCLOSED': 'не заборонено', 'JUDGEPOSITION1': '1', 'JUDGENAME1': 'Іванов А.В.', 'JUDGECODE1': '005014006108', 'MEMBPOSITION1': '1', 'MEMBTYPE1': 'позивач', 'MEMBPOZYVACHTYPE1': 'позивач', 'MEMBVIDPOVIDACHTYPE1': '', 'MEMBOSOBATYPE1': 'юридична', 'MEMBNAME1': 'Національний банк України', 'MEMBSHORT1': 'Позивач 1', 'MEMBOKPO1': '00032106', 'MEMBPOSTADDRESS1': 'вул. Інститутська, 9 м. Київ 01601 Центральна Частина Києва, Київ', 'CHASTDERGVL1': 'FALSE', 'MEMBPOSITION2': '2', 'MEMBTYPE2': 'відповідач', 'MEMBPOZYVACHTYPE2': '', 'MEMBVIDPOVIDACHTYPE2': 'відповідач', 'MEMBOSOBATYPE2': 'юридична', 'MEMBNAME2': 'Спільне підприємство "Айдар - АН - М\'ясо"', 'MEMBSHORT2': 'Відповідач 1', 'MEMBOKPO2': '02176016', 'MEMBPOSTADDRESS2': "вул. Пульного, буд. 2 с.Кам''Янка 92332 Новопсковський район, Луганська область", 'CHASTDERGVL2': 'FALSE', 'MEMBPOSITION3': '3', 'MEMBTYPE3': 'відповідач', 'MEMBPOZYVACHTYPE3': '', 'MEMBVIDPOVIDACHTYPE3': 'відповідач', 'MEMBOSOBATYPE3': 'юридична', 'MEMBNAME3': 'Публічне акціонерне товариство "Комерційний банк Фінансова ініціатива"', 'MEMBSHORT3': 'Відповідач 2', 'MEMBOKPO3': '33299878', 'MEMBPOSTADDRESS3': 'вул. Щорса, буд.7/9 м.Київ 03150 Київська область', 'CHASTDERGVL3': 'FALSE', 'APPVER': '1.30.1.6', 'CRYPTPROVIDER': 'DS13', 'Author': '', 'Description': 'Document', 'Document-state': 'static', 'Updated': '17.08.2017 15:01:09', 'Robots': 'All', 'Keywords': ''}
